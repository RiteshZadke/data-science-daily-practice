# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)]
# (https://colab.research.google.com/github/RiteshZadke/data-science-daily-practice/blob/main/01_python_daily/day_01_conditions.ipynb)

# %% [markdown]
# # Day 01 – Python Conditional Statements
#
# This notebook contains 10 practice problems focused on:
# - Input handling
# - Conditional logic
# - Comparison operators

# %% [markdown]
# Q1. Check if number is positive,negative or zero

# %%
num = int(input("Enter number: "))
if num > 0:
  print("Number is Positive")
elif num < 0:
  print("Number is Negative")
else:
  print("Number is Zero")
# Out:
# Enter number: 5
# Number is Positive

# %% [markdown]
# Q2. Check if number is Even or Odd

# %%
num = int(input("Enter number: "))
if num%2 == 0:
  print(f'{num} is Even')

else:
  print(f'{num} is Odd')
# Out:
# Enter number: 5
# 5 is Odd

# %% [markdown]
# Q3. Check if number which number is greater among two integer

# %%
num1 = int(input("Enter 1st number: "))
num2 = int(input("Enter 2nd number: "))
if num1 > num2:
  print(f"{num1} is greater")
else:
  print(f"{num2} is greater")
# Out:
# Enter 1st number: 6
# Enter 2nd number: 9
# 9 is greater

# %% [markdown]
# Q4. Check if which number is largest among three integers

# %%
num1 = int(input("Enter 1st number: "))
num2 = int(input("Enter 2nd number: "))
num3 = int(input("Enter 3rd number: "))

if num1>num2 and num1>num3:
  print(f"{num1} is largest")
elif num2>num1 and num2>num3:
  print(f"{num2} is largest")
else:
  print(f"{num3} is largest")
# Out:
# Enter 1st number: 5
# Enter 2nd number: 7
# Enter 3rd number: 90
# 90 is largest

# %% [markdown]
# Q5. Check whether number is divisible by both 3 and 5.

# %%
num = int(input("Enter number: "))
if num%3 == 0 and num%5 == 0:
  print(f'{num} is divisible by both 3 and 5')

else:
  print(f"{num} is not divisible by both 3 and 5")
# Out:
# Enter number: 3
# 3 is not divisible by both 3 and 5

# %% [markdown]
# Q6. Check whether student is Distinction,Pass or Fail

# %%
marks = int(input('Enter your marks: '))
if marks>=75:
  print('Distinction')

elif marks>=40 and marks<=74:
  print('Pass')

else:
  print('Fail')
# Out:
# Enter your marks: 4
# Fail

# %% [markdown]
# Q7. Check whether year is a leap year.

# %%
year = int(input('Enter Year: '))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
  print(f'{year} is leap year')

else:
  print(f'{year} is not leap year')
# Out:
# Enter Year: 2
# 2 is not leap year

# %% [markdown]
# Q8. Check whether tempreature Cold,Moderate or Hot

# %%
temp = int(input('Enter tempreature: '))
if temp > 30:
  print("Hot")
elif temp >= 15 and temp <= 30:
  print("Moderate")
else:
  print('Cold')
# Out:
# Enter tempreature: 2
# Cold

# %% [markdown]
# Q9. Check whether number is a multiple of 7.

# %%
num = int(input('Enter number: '))
if num%7==0:
  print(f'{num} is multiple of 7')

else:
  print(f'{num} is not multiple of 7')
# Out:
# Enter number: 5
# 5 is not multiple of 7

# %% [markdown]
# Q10. Implement FizzBuzz: Divisible by 3 → "Fizz" Divisible by 5 → "Buzz" Divisible by both → "FizzBuzz"

# %%
num = int(input('Enter number: '))
if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
elif num%3 == 0:
  print('Fizz')
elif num%5 == 0:
  print('Buzz')
else:
  print('Number is not divisible by 3,5 and both')
# Out:
# Enter number: 90
# FizzBuzz
