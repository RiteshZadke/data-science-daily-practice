# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)]
# (https://colab.research.google.com/github/RiteshZadke/data-science-daily-practice/blob/main/01_python_daily/day_03_strings.ipynb)

# %% [markdown]
# # Day 03 – Python Strings Practice
#
# This notebook contains 10 practice problems focused on:
# - String traversal using loops
# - Character counting and comparisons
# - Reversal and palindrome logic
# - Basic string manipulation techniques

# %% [markdown]
# Q1. Take a string as input and print its length (without using len()).

# %%
string = input("Enter any String: ")
length = 0
for i in string:
  length +=1

print('Length of string is',length)
# Out:
# Enter any String: Python
# Length of string is  6

# %% [markdown]
# Q2. Count the number of vowels in a given string.

# %%
string = input('Enter any string: ')
counter = 0
for ch in string:
  if ch in 'aeiouAEIOU':
    counter += 1
if counter == 0:
  print("There is no vowels in string")
else:
  print("Vowels count is",counter)
# Out:
# Enter any string: ritesh
# Vowels count is 2

# %% [markdown]
# Q3. Reverse a string without using slicing.

# %%
string = input("Enter any string: ")
rev =''
for ch in string:
  rev = ch + rev
print("Reversed string: ",rev)
# Out:
# Enter any string: python
# Reversed string:  nohtyp

# %% [markdown]
# Q4. Check whether a string is a palindrome.

# %%
string = input("Enter any string: ").lower()
rev = ""

for ch in string:
    rev = ch + rev

if rev == string:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter any string: Mom
# Palindrome

# %% [markdown]
# Q5. Count the frequency of each character in a string.

# %%
string = input("Enter any string: ")
dic = {}
for ch in string.lower():
  if ch not in dic:
    dic[ch] = 1

  else :
    dic[ch] += 1
print('Character frequency:',dic)
# Out:
# Enter any string: frequency
# Character frequency: {'f': 1, 'r': 1, 'e': 2, 'q': 1, 'u': 1, 'n': 1, 'c': 1, 'y': 1}

# %% [markdown]
# Q6. Convert all uppercase letters to lowercase and vice versa
#    (without using .swapcase()).

# %%
string = input('Enter string:')
swap_case =''
for ch in string:
  if ch == ch.upper():
    swap_case += ch.lower()
  elif ch == ch.lower():
    swap_case += ch.upper()
  else:
    swap_case += ch
print("Swapcase string:",swap_case)
# Out:
# Enter string:RitESh09
# Swapcase string: rITesH09

# %% [markdown]
# Q7. Remove all spaces from a string.

# %%
string = input("Enter string: ")
result = ""

for ch in string:
    if ch != " ":
        result += ch

print("String without spaces:", result)
# Out:
# Enter string: Data science is fun
# String without spaces: Datascienceisfun

# %% [markdown]
# Q8. Find the first non-repeating character in a string.

# %%
string = input('Enter String: ').lower()
dic = {}
for ch in string:
  if ch not in dic:
    dic[ch] = 1
  else:
    dic[ch] += 1

for ch in string:
  if dic[ch] == 1:
    print("first non-repeating character:",ch)
    break
else:
  print('No non-repeating character found')
# Out:
# Enter String: python
# first non-repeating character: p

# %% [markdown]
# Q9. Check whether two strings are anagrams of each other.

# %%
string1 = input("Enter first string :").replace(" ", "").lower()
string2 = input("Enter second string :").replace(" ", "").lower()

if sorted(string1) == sorted(string2):
  print('Strigs are anagrams')

else:
  print('Strigs are not anagrams')
# Out:
# Enter first string :Earth
# Enter second string :Heart
# Strigs are anagrams

# %% [markdown]
# Q10. Find the longest word in a sentence.

# %%
sen = input('Enter sentence: ')
sen = sen.split()
longest = ''
for word in sen:
  if len(word)>len(longest):
    longest = word
print('Longest word:',longest)
# Out:
# Enter sentence: ritesh is data scientist
# Longest word is : scientist
